# %% [markdown]
# Попробоуем на практике алгоритмы по автоматической оптимизации параметров моделей машинного обучения.

# %%
import pandas as pd
df = pd.read_csv('Heart.csv')
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %% [markdown]
# Подготовить датасет

# %%
import warnings
warnings.filterwarnings('ignore')

df = df.drop('Unnamed: 0', axis =1)

# %%
import numpy as np
# у многих пациентов холестерин =0, что не возможно.
df.Chol.replace(0, np.NaN, inplace =True)
df.Chol.replace(np.nan, df.Chol.mean(), inplace = True)

# %%
df.info() # havent got null obects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    object
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         299 non-null    float64
#  12  Thal       301 non-null    object
#  13  AHD        303 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 33.3+ KB

# %%
df.describe()
# Out:
#               Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# std     22.875003    0.469794    1.161075    0.616226    0.937438
# ...

# %%
from sklearn.preprocessing import LabelEncoder

lab_enc = LabelEncoder()
col = ['Sex','ChestPain','RestECG', 'ExAng', 'Slope','AHD','Thal']

for column in col:
  df[column] = lab_enc.fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    int64
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         299 non-null    float64
#  12  Thal       303 non-null    int64
#  13  AHD        303 non-null    int64
# dtypes: float64(2), int64(12)
# memory usage: 33.3 KB

# %%
df = df.fillna(df.mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    int64
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         303 non-null    float64
#  12  Thal       303 non-null    int64
#  13  AHD        303 non-null    int64
# dtypes: float64(2), int64(12)
# memory usage: 33.3 KB

# %%
df.head(3)
# Out:
#    Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1          3     145   233    1        2    150      0      2.3
# 1   67    1          0     160   286    0        2    108      1      1.5
# 2   67    1          0     120   229    0        2    129      1      2.6
#
#    Slope   Ca  Thal  AHD
# 0      2  0.0     0    0
# 1      1  3.0     1    1
# 2      1  2.0     2    1

# %% [markdown]
# Разделим выборку на обучающее и тестовое подмножество.

# %%
col =df.columns
X = df[col[:-1]]
y = df.AHD

# %%
X.head()
# Out:
#    Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1          3     145   233    1        2    150      0      2.3
# 1   67    1          0     160   286    0        2    108      1      1.5
# 2   67    1          0     120   229    0        2    129      1      2.6
# 3   37    1          1     130   250    0        0    187      0      3.5
# 4   41    0          2     130   204    0        2    172      0      1.4
#
#    Slope   Ca  Thal
# 0      2  0.0     0
# 1      1  3.0     1
# 2      1  2.0     2
# 3      2  0.0     1
# 4      0  0.0     1

# %%
col = df.columns.tolist()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2, random_state= 7)

# %% [markdown]
# Обучим модель логистической регрессии

# %%
result =[] # результирующие значения по дз

# %%
# получение среднего значения для разного random state

mean_train =0
mean_test =0

for i in range(100):
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2, random_state= i)
  model = LogisticRegression()
  model.fit(X_train, y_train)
  mean_test+= model.score(X_test, y_test)
  mean_train+= model.score(X_train, y_train)

mean_train = mean_train/100
mean_test = mean_test/100

result.append(f' initial accuracy of train and test data {mean_train}, {mean_test}')

mean_train, mean_test
d = model.score(X_train, y_train), model.score(X_test, y_test)
d # точности похожи
# Out:
# (0.859504132231405, 0.8360655737704918)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2, random_state= 7)

# %%
from sklearn.metrics import classification_report
y_pred = model.predict(X_test)
report = classification_report(y_true =y_test, y_pred = y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.83        29
#            1       0.89      0.75      0.81        32
#
#     accuracy                           0.82        61
#    macro avg       0.83      0.82      0.82        61
# weighted avg       0.83      0.82      0.82        61

# %% [markdown]
# 5. Подсчитаем основные метрики модели.

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X, y, cv=10, scoring='accuracy')
print(scores)# результат кросс валидации по каждой выборке
result.append(f'cros_val score at accuracy  {scores.mean()}')
print(scores.mean())
# Out:
# [0.87096774 0.83870968 0.74193548 0.96666667 0.83333333 0.7
#  0.83333333 0.9        0.76666667 0.9       ]
# 0.8351612903225807

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X, y, cv=10, scoring='recall')
print(scores)# результат кросс валидации по каждой выборке
result.append(f'cros_val score at recall  {scores.mean()}')
print(scores.mean())
# Out:
# [0.71428571 0.78571429 0.78571429 1.         0.78571429 0.85714286
#  0.71428571 0.85714286 0.57142857 0.78571429]
# 0.7857142857142857

# %%
scores = cross_val_score(model, X, y, cv=10, scoring='f1')
print(scores)# результат кросс валидации по каждой выборке
result.append(f'cros_val score at f1{scores.mean()}')
print(scores.mean())
# Out:
# [0.83333333 0.81481481 0.73333333 0.96296296 0.81481481 0.72727273
#  0.8        0.88888889 0.69565217 0.88      ]
# 0.8151073049333919

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X, y, cv=10, scoring='precision')
print(scores)# результат кросс валидации по каждой выборке
result.append(f'cros_val score at precision  {scores.mean()}')
print(scores.mean())
# Out:
# [1.         0.84615385 0.6875     0.92857143 0.84615385 0.63157895
#  0.90909091 0.92307692 0.88888889 1.        ]
# 0.8661014789304262

# %% [markdown]
# 6. Оптимизируем 3-4 параметра модели используя GridSearchCV.

# %%
# перебор типов модели логистической регрессии
from sklearn.model_selection import GridSearchCV
model = LogisticRegression()
param_grid ={'solver':['bfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']}
#param_grid = {'param_name_in_model': [va,val2,...]} #общий вид сетки с праметрами выглядит как

# %%
grid = GridSearchCV(model, param_grid, cv=10, scoring='accuracy', n_jobs =-1) # GridSearchCV проводит
# скоринг модели для разного количества соседей смотрит точность модели.
grid.fit(X, y)

df = pd.DataFrame(grid.cv_results_)
df[df['mean_test_score']==df['mean_test_score'].max()]
# наибольшую точность получили модели newton-cg и newton-cholesky c точностью 87%
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2       0.080356      0.014979         0.008476        0.002338
# 3       0.015384      0.004188         0.006259        0.003061
#
#       param_solver                         params  split0_test_score  \
# 2        newton-cg        {'solver': 'newton-cg'}           0.870968
# 3  newton-cholesky  {'solver': 'newton-cholesky'}           0.870968
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 2           0.806452           0.774194           0.966667           0.833333
# 3           0.806452           0.774194           0.966667           0.833333
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 2                0.7           0.866667                0.9           0.766667
# 3                0.7           0.866667                0.9           0.766667
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# ...

# %%
max = df.mean_test_score[df['mean_test_score']==df['mean_test_score'].max()]
result.append(f'LogisticRegression grid score {max}')
max
# Out:
# 2    0.835161
# 3    0.835161
# Name: mean_test_score, dtype: float64

# %%
import numpy as np
model = LogisticRegression(solver ='newton-cg' )
param_grid ={'max_iter':np.arange(100, 1001, 100)}
#param_grid = {'param_name_in_model': [va,val2,...]} #выглядит как

grid = GridSearchCV(model, param_grid, cv=10, scoring='accuracy', n_jobs =-1) # GridSearchCV проводит
# скоринг модели для разного количества соседей смотрит точность модели.
grid.fit(X, y)

df = pd.DataFrame(grid.cv_results_) # от количества итераций точность не меняется.
df[df['mean_test_score']==df['mean_test_score'].max()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.085665      0.026938         0.005663        0.002181
# 1       0.082921      0.019651         0.006672        0.003130
# 2       0.052267      0.006353         0.004883        0.001566
# 3       0.055296      0.014763         0.004077        0.000154
# 4       0.050876      0.005547         0.004175        0.000151
# 5       0.049950      0.005231         0.004410        0.000829
# 6       0.054465      0.011059         0.005088        0.001895
# 7       0.049536      0.004635         0.004267        0.000589
# 8       0.049537      0.004658         0.004221        0.000257
# 9       0.050664      0.004181         0.004232        0.000712
#
#   param_max_iter              params  split0_test_score  split1_test_score  \
# 0            100   {'max_iter': 100}           0.870968           0.806452
# 1            200   {'max_iter': 200}           0.870968           0.806452
# ...

# %%
model = LogisticRegression(solver ='newton-cg' )
param_grid ={'fit_intercept':[True, False]}
#param_grid = {'param_name_in_model': [va,val2,...]} #выглядит как

grid = GridSearchCV(model, param_grid, cv=10, scoring='accuracy', n_jobs =-1) # GridSearchCV проводит
# скоринг модели для разного количества соседей смотрит точность модели.
grid.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(solver='newton-cg'), n_jobs=-1,
#              param_grid={'fit_intercept': [True, False]}, scoring='accuracy')

# %%
df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.085665      0.026938         0.005663        0.002181
# 1       0.082921      0.019651         0.006672        0.003130
# 2       0.052267      0.006353         0.004883        0.001566
# 3       0.055296      0.014763         0.004077        0.000154
# 4       0.050876      0.005547         0.004175        0.000151
#
#   param_max_iter             params  split0_test_score  split1_test_score  \
# 0            100  {'max_iter': 100}           0.870968           0.806452
# 1            200  {'max_iter': 200}           0.870968           0.806452
# 2            300  {'max_iter': 300}           0.870968           0.806452
# 3            400  {'max_iter': 400}           0.870968           0.806452
# 4            500  {'max_iter': 500}           0.870968           0.806452
#
#    split2_test_score  split3_test_score  split4_test_score  split5_test_score  \
# ...

# %%
df = pd.DataFrame(grid.cv_results_) # с учетом константы  (true) точность получилась выше.
#Поэтому ее можно оставимть (Default =True)
df[df['mean_test_score']==df['mean_test_score'].max()]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.0549      0.012488         0.004115        0.000086
#
#   param_fit_intercept                   params  split0_test_score  \
# 0                True  {'fit_intercept': True}           0.870968
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.806452           0.774194           0.966667           0.833333
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0                0.7           0.866667                0.9           0.766667
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.866667         0.835161        0.072298                1

# %% [markdown]
# Попробуем оптимизировать с помощью RandomizedSearchCV.

# %%
from sklearn.model_selection import RandomizedSearchCV

model = LogisticRegression()

param_grid = {'solver':['bfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
              'C':np.arange(0.1, 1.1, 0.1)} # C- параметр регуляризации.На сколько он режет
#не нужные коэффициенты
grid = RandomizedSearchCV(model, param_grid, cv=10, scoring='accuracy')
grid.fit(X,y)
print(grid.best_score_)
print(grid.best_estimator_)
# Out:
# 0.8386021505376343
# LogisticRegression(C=0.30000000000000004, solver='newton-cg')

# %%
result.append(f'RandomizedSearchCV score {grid.best_score_}')

# %% [markdown]
# c) *Добавьте в п. 6b 2-5 моделей классификации и вариации их параметров.

# %%
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.svm import SVC
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from scipy.stats import uniform
from sklearn.neighbors import KNeighborsClassifier

# %%
models=[
      {'name':'RF',"model": RandomForestClassifier(), 'params':{'n_estimators':[100,150,200], 'criterion':['gini', 'entropy'], 'max_depth':[3,5]}},
      {'name':'KN',"model": KNeighborsClassifier(), 'params':{'n_neighbors':list(range(1,10)),'weights': ['uniform', 'distance'], 'p':[1,2,3]}},

]
res=[]
for v in  models:
    res.append((v['name'], RandomizedSearchCV(v['model'], v['params'], cv=10, n_jobs =-1).fit(X_train, y_train)))

# %% [markdown]
# d) Повторите п. 5 после каждого итогового изменения параметров.

# %%
for r in res:
    print(r[0], r[1].best_score_, r[1].best_params_)
# Out:
# RF 0.8383333333333333 {'n_estimators': 100, 'max_depth': 3, 'criterion': 'entropy'}
# KN 0.6813333333333333 {'weights': 'uniform', 'p': 1, 'n_neighbors': 6}

# %%
y_pred = res[0][1].best_estimator_.predict(X_test)
wrong = y_pred != y_test

X_wrong, y_wrong, y_true_wrong = X_test[wrong], y_pred[wrong], y_test[wrong]
X_wrong, y_wrong, y_true_wrong
# Out:
# (     Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
#  57    41    1          0     110   172    0        2    158      0      0.0
#  66    60    1          1     140   185    0        2    155      0      3.0
#  114   62    0          1     130   263    0        0     97      0      1.2
#  80    45    1          0     104   208    0        2    148      1      3.0
#  74    44    1          0     110   197    0        2    177      0      0.0
#  188   54    1          2     192   283    0        2    195      0      0.0
#  298   45    1          3     110   264    0        0    132      0      1.2
#  176   52    1          0     108   233    1        0    147      0      0.1
#  261   58    0          2     136   319    1        2    152      0      0.0
#  278   57    1          2     154   232    0        2    164      0      0.0
#  22    58    1          2     120   284    0        2    160      0      1.8
#
#       Slope   Ca  Thal
# ...

# %% [markdown]
# 7. Сформулируйте выводы по проделанной работе:
# a) Сравните метрики построенных моделей.

# %%
'''
По метрикам видно, что модели логистической регресси ведет себя прилично (score =0.83.7) процента на тетовой выборке.
Улучшение качества модели получилось на кроссвалидации логисточеской регрессии на precision - 86.6 %
# Out:
# '\nПо метрикам видно, что модели линейной регресси ведет себя прилично (sccore =0.88). Методика улучшения параметров модели результатов не дало.\n'

# %%
result
# Out:
# [' initial accuracy of train and test data 0.8595867768595046, 0.8378688524590163',
#  'cros_val score at accuracy  0.8351612903225807',
#  'cros_val score at recall  0.7857142857142857',
#  'cros_val score at f10.8151073049333919',
#  'cros_val score at precision  0.8661014789304262',
#  'LogisticRegression grid score 2    0.835161\n3    0.835161\nName: mean_test_score, dtype: float64',
#  'RandomizedSearchCV score 0.8386021505376343']

# %% [markdown]
# b) *Сравните с полученными результатами в домашнем задании по теме «Ансамблирование».

# %%
'''
Данные по ансамблированию:
['DecisionTreeClassifier_ score (train/test) [0.8514986376021798, 0.842391304347826]',
 'RandomForestClassifier_ score (train/test) [0.8651226158038147, 0.8586956521739131]',
 'bagging_ score (train/test) [0.6042265499194847, 0.5833296558970317]',
 'stacking_ score (train/test) with lin_reg [0.5853250610231586, 0.5623643202940767]',
 'stacking_ score (train/test) without lin_reg [0.5895391838565098, 0.5587998340697409]']

Ансамблирование резульатов не дало. Лучшая метрика получилась на обычном RandomForestClassifier. На тестовой выборке точность ссоставляет 0.858.

На основании этих двух работ можно сделать вывод, что лучшее качество модели получается у модели логистичекой регрессиии с scoring='precision'.

'''
# Out:
# '\n\n\n'
